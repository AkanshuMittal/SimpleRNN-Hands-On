# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN,Embedding,Dense
from tensorflow.keras.utils import Sequence
# Out:
# WARNING:tensorflow:From c:\Users\akans\OneDrive\Desktop\SimpleRNN\venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the imdb dataset 
max_features = 1000   # Vocabulary_size
(X_train, y_train),(X_test,y_test)=imdb.load_data(num_words=max_features)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 8s 0us/step

# %%
# Shape of the data 
X_train.shape

# %%
X_train[0]

# %%
# Inspect a sample review and its label
